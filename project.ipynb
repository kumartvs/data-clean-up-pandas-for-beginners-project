# %% [markdown]
# # Basic Python Practices
#
# #### Exercise 00. Variable Declaration
#
# Define the following variables with values of your choice:
#
# - A variable that stores your name (text).
# - A variable that stores your age (integer).
# - A variable that indicates if you like programming (true or false).
# - A variable that stores your average grade (decimal number).

# %%
# Declare your variables here.

#Example
greeting = "Hello world"
name = "Venkata"
age = 30        
is_student = True

# %% [markdown]
# - Create a list with your five favorite numbers and print it.

# %%
# Favorite numbers list
favorite_numbers = [7, 42, 3.14, 100, 99]
for num in favorite_numbers:
    print(num)
# Out:
# 7
# 42
# 3.14
# 100
# 99

# %% [markdown]
# - Create a dictionary that stores a student's information and print it:
#
#         - Name
#         - Age
#         - Final grade

# %%
#TODO
student_info = {
    "name": "Venkata",
    "age": "30",
    "grade": "A"
    }
for key, value in student_info.items():
    print(f"{key}: {value}")
# Out:
# name: Venkata
# age: 30
# grade: A

# %% [markdown]
# #### Exercise 01. Basic data analysis with native Python structures.
# Create a list with the grades of 5 students: [8.5, 9.2, 7.8, 8.9, 10].
#
# - Calculate the average of the grades.

# %%
student_grades = [8.5, 9.2, 7.8, 8.9, 10]
for grade in student_grades:
    print(grade)
# Out:
# 8.5
# 9.2
# 7.8
# 8.9
# 10

# %%
# Calculate the average of the grades  
student_grades = [8.5, 9.2, 7.8, 8.9, 10]                                         
average = sum(student_grades) / len(student_grades)      
print(f"Average grade: {average}")
# Out:
# Average grade: 8.879999999999999

# %% [markdown]
# - Find the highest and lowest grade.

# %%
# Find the highest and lowest grades
student_grades = [8.5, 9.2, 7.8, 8.9, 10]
highest_grade = max(student_grades)
print(f"Highest grade: {highest_grade}")
# Out:
# Highest grade: 10

# %%
# TODOlowest_grade = min(student_grades)
student_grades = [8.5, 9.2, 7.8, 8.9, 10]           
lowest_grade = min(student_grades)
print(f"Lowest grade: {lowest_grade}")
# Out:
# Lowest grade: 7.8

# %% [markdown]
# # Real estate data cleaning with Pandas for efficient analysis
#
# This is a real dataset that was downloaded using web scraping techniques. The data contains records from **Fotocasa**, one of the most popular real estate websites in Spain. Please do not perform web scraping unless it is for academic purposes.
#
# The dataset was downloaded a few years ago by Henry Navarro, and no economic benefit was obtained from it.
#
# It contains thousands of real house listings published on the website www.fotocasa.com. Your goal is to extract as much information as possible with the data science knowledge you have acquired so far.
#
# Let's get started!
#
# - First, let's read and explore the dataset.

# %%
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds # mostramos todo
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# - Display the first rows of the CSV file.

# %%
ds.head(1) # displays first row
# Out:
#    Unnamed: 0  id_realEstates  isNew          realEstate_name  \
# 0           1       153771986  False  ferrari 57 inmobiliaria
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
#
#    bathrooms  surface   price  ... level4Id level5Id level6Id level7Id  \
# 0        2.0    103.0  195000  ...        0        0        0        0
#
#   level8Id accuracy          latitude          longitude zipCode customZone
# 0        0        0  40,2948276786438  -3,44402412135624     NaN        NaN
#
# [1 rows x 37 columns]

# %%
ds.head()
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 1       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 2       916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 3       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 4       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
#
# ...

# %% [markdown]
# Perfect, this was a small practice. Now let's begin with the real exercises!

# %% [markdown]
# #### Exercise 01. What is the most expensive house in the entire dataset? (★☆☆)
#
# Print the address and price of the selected house. For example:
#
# `The house located at Calle del Prado, Nº20 is the most expensive, and its price is 5000000 USD.`

# %%
# Find the most expensive house
most_expensive_idx = ds['price'].idxmax()
most_expensive_house = ds.loc[most_expensive_idx]
print(most_expensive_house)
address = most_expensive_house['address']
price = most_expensive_house['price']
print(f"The house located at {address} is the most expensive, and its price is {price} USD.")
# Out:
# Unnamed: 0                                                      13111
# id_realEstates                                              132042636
# isNew                                                           False
# realEstate_name                            engel volkers torrelodones
# phone_realEstate                                          911798512.0
# url_inmueble        https://www.fotocasa.es/es/comprar/vivienda/vi...
# rooms                                                            19.0
# bathrooms                                                         NaN
# surface                                                           NaN
# price                                                         8500000
# date                                             2019-12-19T12:29:00Z
# description         El Palacio de El Enebral, la finca fue propied...
# address                                                   El Escorial
# ...

# %% [markdown]
# #### Exercise 02. What is the cheapest house in the dataset? (★☆☆)
#
# This exercise is similar to the previous one, except now we are looking for the house with the lowest price. Remember to print the address and price of the selected house. For example:
#
# `The house located at Calle Alcalá, Nº58 is the cheapest, and its price is 12000 USD.`

# %%
# Find the cheapest house
cheapest_idx = ds['price'].idxmin()
print (cheapest_idx)
cheapest_house = ds.loc[cheapest_idx]

address = cheapest_house['address']
price = cheapest_house['price']
print(f"The house located at {address} is the cheapest, and its price is {price} USD.")
# Out:
# 366
# The house located at Parla is the cheapest, and its price is 0 USD.

# %% [markdown]
# #### Exercise 03. What is the largest and smallest house in the dataset? (★☆☆)
#
# Print the address and area of the selected houses. For example:
#
# `The largest house is located at Calle Gran Vía, Nº38, and its area is 5000 square meters.`
#
# `The smallest house is located at Calle Mayor, Nº12, and its area is 200 square meters.`
#
# This exercise is similar to the previous one, but we are looking for the largest and smallest houses based on their area.

# %%
#Find the largest house
largest_idx = ds['surface'].idxmax()
largest_house = ds.loc[largest_idx]
address = largest_house['address']
size = largest_house['surface']
print(f"The house located at {address} is the largest, and its size is {size} sqft.")   

# Find the smallest house  
smallest_idx = ds['surface'].idxmin()
smallest_house = ds.loc[smallest_idx]
address = smallest_house['address']
size = smallest_house['surface']
print(f"The house located at {address} is the smallest, and its size is {size} sqft.")
# Out:
# The house located at Sevilla la Nueva is the largest, and its size is 249000.0 sqft.
# The house located at Calle Amparo,  Madrid Capital is the smallest, and its size is 15.0 sqft.

# %% [markdown]
# #### Exercise 04. How many unique populations are in the dataset? (★☆☆)
#
# Count the number of unique populations in the 'level5' column and print the names of the populations separated by commas. For example:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# Get unique populations
populations = ds['level5'].unique()
num_populations = ds['level5'].nunique()
print(f"Number of unique populations: {num_populations}")
print(", ".join(populations))
# Out:
# Number of unique populations: 168
# ...

# %% [markdown]
# #### Exercise 05. Does the dataset contain null values (NAs)? (★☆☆)
#
# Print a boolean (`True` or `False`) to check if there are null values, followed by the columns that contain NAs.

# %%
# Check if there are any null values
has_nulls = ds.isnull().any().any()
print(f"Dataset contains null values: {has_nulls}")

# Show only columns with null values
columns_with_nulls = ds.isnull().any()[ds.isnull().any()]
print("\nColumns with null values:")
print(columns_with_nulls)

# Count nulls in columns that have them
null_counts = ds.isnull().sum()[ds.isnull().sum() > 0]
print("\nNull counts in affected columns:")
print(null_counts)
# Out:
# Dataset contains null values: True
#
# Columns with null values:
# realEstate_name     True
# phone_realEstate    True
# rooms               True
# bathrooms           True
# surface             True
# description         True
# level4              True
# level6              True
# level7              True
# level8              True
# zipCode             True
# customZone          True
# dtype: bool
#
# Null counts in affected columns:
# realEstate_name        10
# phone_realEstate      794
# rooms                 353
# bathrooms             345
# surface              1250
# description           142
# level4               6643
# level6              14627
# level7               2277
# level8               8579
# zipCode             15335
# customZone          15335
# dtype: int64

# %% [markdown]
# #### Exercise 06. Remove the null values (NAs) from the dataset, if applicable (★★☆)
#
# After removing the null values, compare the size of the DataFrame before and after the removal.

# %%
# Compare size before and after removing null values
size_before = len(ds)
print(f"Dataset size before removing nulls: {size_before} rows")

# Remove rows with any null values
ds_clean = ds.dropna()

size_after = len(ds_clean)
print(f"Dataset size after removing nulls: {size_after} rows")

# Show the difference
rows_removed = size_before - size_after
print(f"Rows removed: {rows_removed}")
print(f"Percentage removed: {(rows_removed / size_before) * 100:.2f}%")
# Out:
# Dataset size before removing nulls: 15335 rows
# Dataset size after removing nulls: 0 rows
# Rows removed: 15335
# Percentage removed: 100.00%

# %% [markdown]
# #### Exercise 07. What is the average price in the population of "Arroyomolinos (Madrid)"? (★★☆)
#
# Print the value obtained from the 'level5' column.

# %%
# Filter for Arroyomolinos (Madrid)
arroyomolinos = ds[ds['level5'] == 'Arroyomolinos (Madrid)']

# Calculate average price
avg_price = arroyomolinos['price'].mean()
print(f"Average price in Arroyomolinos (Madrid): {avg_price} USD")

# Additional info
print(f"Number of houses in Arroyomolinos (Madrid): {len(arroyomolinos)}")

# %% [markdown]
# #### Exercise 08. Plot the histogram of prices for the population of "Arroyomolinos (Madrid)" and explain what you observe (★★☆)
#
# Print the histogram of the prices and write a brief analysis of the plot in the Markdown cell.

# %%
import matplotlib.pyplot as plt

# Plot the histogram of prices
plt.hist(ds['price'], bins=30, color='blue', edgecolor='black')
plt.title('Distribution of House Prices')
plt.xlabel('Price (USD)')
# Out:
# Text(0.5, 0, 'Price (USD)')

# %%
# Create a list with grades of 5 students
student_grades = [85, 92, 78, 95, 88]

print("Student Grades:", student_grades)
print(f"Average grade: {sum(student_grades) / len(student_grades):.2f}")
print(f"Highest grade: {max(student_grades)}")
print(f"Lowest grade: {min(student_grades)}")
